# %% [markdown]
# # Telegram Torrent Downloader Bot - Colab Setup
#
# This notebook provides a complete environment to run the MTProto uploader bot without external cloud storage.

# %%
# 1. Install System Dependencies and Python Packages
# !apt-get update -y
# !apt-get install -y aria2
# !pip install -r requirements.txt
# !pip install pyrogram TgCrypto aiofiles aiohttp psutil tqdm aiojobs jsonschema pytest pytest-asyncio

# %%
# 2. Create Required Directories
import os
os.makedirs("/content/downloads", exist_ok=True)
os.makedirs("/content/logs", exist_ok=True)
print("Directories created successfully.")

# %%
# 3. Set Environment Variables
# ⚠️ SECURITY WARNING: Do NOT share this notebook with anyone! ⚠️
import os

# Required Settings
os.environ["API_ID"] = "12345"  # Replace with your API ID
os.environ["API_HASH"] = "abcdef1234567890"  # Replace with your API Hash
os.environ["USER_SESSION_STRING"] = "1BJWap_MBz..."  # Replace with your Session String
os.environ["DUMP_CHANNEL_ID"] = "-1001234567890"  # Replace with Dump Channel ID
os.environ["ADMIN_CHANNEL_ID"] = "-1009876543210"  # Replace with Admin Channel ID

# Optional Settings (Defaults applied)
os.environ["DOWNLOAD_DIR"] = "/content/downloads"
os.environ["MAX_DISK_USED_GB"] = "70.0"
os.environ["RESUME_DISK_USED_GB"] = "40.0"
os.environ["UPLOAD_WORKERS"] = "3"
os.environ["SPLIT_SIZE_BYTES"] = "4194304000"  # ~3.9 GiB
os.environ["LOG_FILE"] = "/content/logs/bot.log"

print("Environment Variables Set.")

# %%
# 4. Start Aria2 and Run the Bot
# !aria2c --daemon --enable-rpc --rpc-listen-all=true --rpc-listen-port=6800 --max-concurrent-downloads=5 --dir=/content/downloads
import time
time.sleep(1)
# !python run_bot.py
