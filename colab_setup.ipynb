# %% [markdown]
# # Telegram Torrent Bot - Google Colab Setup
#
# This notebook sets up the environment, installs dependencies, mounts Google Drive, and starts the bot server.
#
# **Important:** Colab has strict limitations and will terminate your runtime if you close your browser or leave it idle. Keep this tab open while downloading.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !apt-get update
# !apt-get install -y python3-libtorrent aria2
# !pip install python-telegram-bot fastapi uvicorn google-api-python-client google-auth-httplib2 google-auth-oauthlib

# %%
import os

# Change this path to where your bot files are stored in Drive
BOT_DIR = '/content/drive/MyDrive/TelegramTorrentBot'

if not os.path.exists(BOT_DIR):
    print(f"Directory {BOT_DIR} does not exist. Please upload the project files there.")
else:
    os.chdir(BOT_DIR)
    print("Starting the bot server...")
    # Run the server. You must have config.cfg properly configured in that folder.
    # !python server.py
